# %%
import pandas as pd
import numpy as np
import datetime
from collections import Counter
from py2neo import Graph, Node, Relationship
from sklearn.metrics.pairwise import cosine_similarity

# %%
graph = Graph()

# %%
query = """
            MATCH (m:Movie)-[:HAS_GENRE]->(g:Genre)
            RETURN  m.movieID as movieID, COALESCE(g.name) as genres
            ORDER BY m.movieID ASC
            """
dffilmgen = pd.DataFrame(graph.run(query).data())

# %%
dffilmgen.groupby('genres').count()
# Out:
#                   movieID
# genres
# Action               1828
# Adventure            1263
# Animation             611
# Children              664
# Comedy               3756
# Crime                1199
# Documentary           440
# Drama                4361
# Fantasy               779
# Film-Noir              87
# Horror                978
# IMAX                  158
# Musical               334
# Mystery               573
# Romance              1596
# Sci-Fi                980
# Thriller             1894
# War                   382
# Western               167
# no genres listed       34

# %%
dffilmgen = pd.get_dummies(dffilmgen, columns=['genres']).groupby('movieID').sum()

# %%
query = """
        MATCH (m:Movie)
        RETURN m.movieID as movieID,m.avgrating as avgrating, m.year as year, m.lang as lang
            """
dffilm = pd.DataFrame(graph.run(query).data())

# %%
dffilm = dffilm[["movieID","avgrating"]]

# %%
dffilm[dffilm.columns[dffilm.isnull().any()]].isnull().sum()
# Out:
# avgrating    18
# dtype: int64

# %%
dffilm["avgrating"].fillna(0, inplace=True)

# %%
dffilm[dffilm.columns[dffilm.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
cos_genres = cosine_similarity(dffilmgen.values)*0.7
cos_rating = cosine_similarity(dffilm.values)*0.3
cos = cos_genres+cos_rating
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-135-71df5bc22300> in <module>
# ----> 1 cos_genres = cosine_similarity(dffilmgen.values)*0.7
#       2 cos_rating = cosine_similarity(dffilm.values)*0.3
#       3 cos = cos_genres+cos_rating
#
# ~/environments/MovieSocialApp/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1034
#    1035     K = safe_sparse_dot(X_normalized, Y_normalized.T,
# -> 1036                         dense_output=dense_output)
#    1037
#    1038     return K
#
# ~/environments/MovieSocialApp/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     140         return ret
#     141     else:
# --> 142         return np.dot(a, b)
#     143
#     144
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# MemoryError: Unable to allocate array with shape (9742, 9742) and data type float64

# %%
movies_sim = pd.DataFrame(cos, columns=dffilm['movieID'], index=dffilm['movieID'])

# %%
movies_sim
# Out:
# movieID    147410    147657    147662    147936    148166    148172    148238  \
# movieID
# 147410   1.000000  0.932379  0.794868  0.777460  0.834164  0.700000  0.794868
# 147657   0.932379  1.000000  0.700000  0.700000  0.700000  0.700000  0.700000
# 147662   0.794868  0.700000  1.000000  0.944949  0.912132  0.700000  1.000000
# 147936   0.777460  0.700000  0.944949  1.000000  0.873205  0.700000  0.944949
# 148166   0.834164  0.700000  0.912132  0.873205  1.000000  0.700000  0.912132
# ...           ...       ...       ...       ...       ...       ...       ...
# 14       0.876401  0.761756  0.781219  0.761757  0.825153  0.761755  0.781218
# 15       0.918790  0.786410  0.808884  0.786411  0.859615  0.686409  0.808883
# 16       0.679831  0.679829  0.679828  0.853035  0.679829  0.679828  0.679828
# 17       0.778219  0.683349  0.683348  0.683350  0.683349  0.805822  0.683348
# 18       0.819833  0.685668  0.897799  0.858874  0.985667  0.685667  0.897799
#
# movieID    148424    148482    148592  ...    9         10        11      \
# movieID                                ...
# 147410   0.889737  0.700000  0.777460  ...  0.795443  0.755655  0.758868
# 147657   0.944949  0.700000  0.800000  ...  0.661278  0.660785  0.663998
# 147662   0.700000  0.700000  0.700000  ...  0.767342  0.660784  0.813997
# 147936   0.700000  0.700000  0.700000  ...  0.747881  0.783260  0.908948
# 148166   0.700000  0.700000  0.700000  ...  0.811277  0.660784  0.876129
# ...           ...       ...       ...  ...       ...       ...       ...
# 14       0.675154  0.825153  0.761755  ...  0.923432  0.804397  0.805012
# 15       0.686410  0.686409  0.686409  ...  0.866665  0.815729  0.817035
# 16       0.679829  0.679828  0.679828  ...  0.696941  0.908931  0.909810
# 17       0.683349  0.895480  0.805823  ...  0.907458  0.845152  0.696249
# 18       0.685668  0.685667  0.685667  ...  0.843960  0.693762  0.907148
#
# movieID    12        13        14        15        16        17        18
# movieID
# 147410   0.820343  0.680617  0.876401  0.918790  0.679831  0.778219  0.819833
# 147657   0.686178  0.680616  0.761756  0.786410  0.679829  0.683349  0.685668
# 147662   0.686177  0.680615  0.781219  0.808884  0.679828  0.683348  0.897799
# 147936   0.686178  0.680617  0.761757  0.786411  0.853035  0.683350  0.858874
# 148166   0.686177  0.680616  0.825153  0.859615  0.679829  0.683349  0.985667
# ...           ...       ...       ...       ...       ...       ...       ...
# 14       0.848374  0.699656  1.000000  0.958100  0.699753  0.911303  0.848543
# 15       0.873204  0.699481  0.958100  1.000000  0.699345  0.822317  0.873195
# 16       0.699395  0.699992  0.699753  0.699345  1.000000  0.699829  0.699496
# 17       0.911999  0.699895  0.911303  0.822317  0.699829  1.000000  0.699912
# 18       0.699995  0.699615  0.848543  0.873195  0.699496  0.699912  1.000000
#
# [9742 rows x 9742 columns]

# %%
def get_similar(movieID):
    df = movies_sim.loc[movies_sim.index == movieID].reset_index(). \
            melt(id_vars='movieID', var_name='sim_moveId', value_name='sim_score'). \
            sort_values('sim_score', axis=0, ascending=False)[1:11]
    return df
movies_similarity = pd.DataFrame(columns=['movieID','sim_moveId','sim_score'])

# %%
for x in movies_sim.index.tolist():
    movies_similarity = movies_similarity.append(get_similar(x))

# %%
movies_similarity
# Out:
#      movieID sim_moveId  sim_score
# 2355  147410      93510   1.000000
# 1706  147410      72605   1.000000
# 559   147410     187717   0.973861
# 1757  147410      74095   0.968328
# 2539  147410      98061   0.968328
# ...      ...        ...        ...
# 9482      18        937   0.994080
# 9528      18       1006   0.994064
# 8154      18       1845   0.993985
# 8214      18       1938   0.993980
# 8780      18       2632   0.993948
#
# [97420 rows x 3 columns]

# %%
movies_similarity.to_csv('../Data/movie_sim.csv', index=False)

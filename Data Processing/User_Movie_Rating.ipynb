# %%
from datetime import datetime
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv('../Data/reviews.csv'))

# %%
df = df[["rating", "userId", "movieId"]]

# %%
df
# Out:
#         rating  userId  movieId
# 0          4.0       1        1
# 1          4.0       1        3
# 2          4.0       1        6
# 3          5.0       1       47
# 4          5.0       1       50
# ...        ...     ...      ...
# 100831     4.0     610   166534
# 100832     5.0     610   168248
# 100833     5.0     610   168250
# 100834     5.0     610   168252
# 100835     3.0     610   170875
#
# [100836 rows x 3 columns]

# %%
df.to_csv('../Data/ratings.csv', index=False)

# %%
from random_username.generate import generate_username
import pandas as pd
from passlib.hash import bcrypt

# %%
generate_username(610)
# Out:
# ['lovesickMandrill7',
#  'gloomyToucan0',
#  'amazedMandrill3',
#  'amazedFish2',
#  'morbidCake1',
#  'spiritedViper1',
#  'artisticCheese7',
#  'morbidCrane1',
#  'thrilledWasp7',
#  'sadDotterel3',
#  'grumpyLizard9',
#  'drearyCheetah9',
#  'humorousCake0',
#  'morbidCamel5',
#  'cruelSnail7',
#  'trustingSalt2',
#  'ferventDingo7',
#  'finickyWeaver8',
#  'troubledFalcon3',
#  'amazedFish3',
#  'eagerMare7',
#  'shamefulZebra0',
#  'offendedFerret5',
#  'lazyOtter2',
#  'obsessedSwift5',
#  'worldlyGranola5',
#  'wrathfulHeron7',
#  'cynicalWildfowl9',
#  'betrayedHawk6',
#  'tautSyrup5',
#  'sheepishDove6',
#  'peacefulApricots6',
#  'ashamedPear4',
#  'insecureCamel9',
#  'similarGelding3',
#  'wakefulWidgeon1',
#  'cynicalToucan9',
#  'sadDove6',
#  'holisticThrushe3',
#  'awedSardines6',
#  'awedPepper6',
#  'ferventBass7',
#  'aboardOil3',
#  'dearKitten6',
#  'mereApricots9',
#  'adoringPoultry4',
#  'solidIguana9',
#  'gloomyPudding8',
#  'grumpyMoth1',
# ...

# %%
d = []
i = 610
ps = bcrypt.encrypt("test")
for p in range(1, 611):
    d.append({'userID': p, 'username': str(generate_username())[2:-2], 'password':
        ps})

ds = pd.DataFrame(d)
# Out:
# /home/reddwarf/environments/MovieSocialApp/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: the method passlib.handlers.bcrypt.bcrypt.encrypt() is deprecated as of Passlib 1.7, and will be removed in Passlib 2.0, use .hash() instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ds.to_csv("users.csv", index=False)

# %%
str(generate_username())[2:-2]
# Out:
# 'giddyGatorade7'
